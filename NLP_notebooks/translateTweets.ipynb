# %%
import pandas as pd
import googletrans
import re
import time
from googletrans import Translator

# %%
df2=pd.read_csv("../data/all_Tweets_2022-11-28(argentina).csv")

# %%
df3=pd.read_csv("../data/all_Tweets_2022-11-28(argentina)(1).csv")

# %%
df4=pd.read_csv("../data/all_Tweets_2022-11-28(argentina)(2).csv")

# %%
for i in range(len(df3['text'])):
    translator = Translator()
    val=str(df3['text'][i])
    df3['text'][i]=translator.translate(val).text
    print(i)
    print(df3['text'][i])
# Out:
# C:\Users\EFRACK\AppData\Local\Temp\ipykernel_2376\2595222588.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['text'][i]=translator.translate(val).text
# 0
# @burrovan Argentina 🇦🇷!!! Brazil 🇧🇷!!!
# 1
# @Politica_ln Outburst? Against Argentine society??? Hahahaha...He only tells the truth. I totally agree with the words of Luis Juez
# 2
# I was going to tell my brother CE VIU NE THE ITALO IS IN ARGENTINA and my brother laughing saying I know I just left because I was very ashamed of others
# 3
# @Canelo these are Argentina, they touch Messi, they touch the country. Don't hate the fart, look closely, ask. Arguing for nothing.
# 4
# ...

# %%
df2['text']
# Out:
# 0       All calves when Maria Becerra releases her alb...
# 1       @_Lauradimarco of those 20, taking the period ...
# 2       @bluish97 @edutorresr @antonio_nelli Nono, Hip...
# 3       @edufek that is a joke in bad taste, that this...
# 4       @Eldi2 @brunodigennaro9 @alvaritomorales is ju...
#                               ...
# 1793    I think yesterday was a month of Jin in Argent...
# 1794    @outayior @choated the key of Brazil has nothi...
# 1795    @Tntsportsbr of course makes fucking and our b...
# 1796    @aguerosergiokun I don't see any from Argentin...
# 1797    @maycolgx @renacova YES I see t -shirts from t...
# Name: text, Length: 1798, dtype: object

# %%
dfT1 =  df2['text']

# %%
#dfT1.to_csv('../data/ARG-en-1.csv')
